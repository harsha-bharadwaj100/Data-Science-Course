# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Algerian_forest_fires_dataset_UPDATE.csv")
df.head()
# Out:
#    day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29   57   18    0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29   61   13    1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26   82   22   13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25   89   13    2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27   77   16    0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI   Classes  region
# 0  0.5  not fire       0
# 1  0.4  not fire       0
# 2  0.1  not fire       0
# 3  0.0  not fire       0
# 4  0.5  not fire       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          242 non-null    int64
#  1   month        242 non-null    int64
#  2   year         242 non-null    int64
#  3   Temperature  242 non-null    int64
#  4    RH          242 non-null    int64
#  5    Ws          242 non-null    int64
#  6   Rain         242 non-null    float64
#  7   FFMC         242 non-null    float64
#  8   DMC          242 non-null    float64
#  9   DC           242 non-null    float64
#  10  ISI          242 non-null    float64
#  11  BUI          242 non-null    float64
#  12  FWI          242 non-null    float64
#  13  Classes      242 non-null    object
#  14  region       242 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.5+ KB

# %%
df.describe(include="all")
# Out:
#                day       month    year  Temperature          RH          Ws  \
# count   242.000000  242.000000   242.0   242.000000  242.000000  242.000000
# unique         NaN         NaN     NaN          NaN         NaN         NaN
# top            NaN         NaN     NaN          NaN         NaN         NaN
# freq           NaN         NaN     NaN          NaN         NaN         NaN
# mean     15.822314    7.508264  2012.0    32.152893   62.004132   15.508264
# std       8.809501    1.112888     0.0     3.635545   14.847635    2.808171
# min       1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%       8.000000    7.000000  2012.0    30.000000   52.250000   14.000000
# 50%      16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%      23.000000    8.000000  2012.0    35.000000   73.750000   17.000000
# max      31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain         FFMC         DMC          DC         ISI  \
# count   242.000000  242.000000  242.000000  242.000000  242.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean      0.763223   77.928099   14.730992   49.601240    4.759504
# std       2.007354   14.316912   12.393811   47.690192    4.154248
# min       0.000000   28.600000    0.700000    6.900000    0.000000
# 25%       0.000000   72.375000    5.800000   14.325000    1.400000
# 50%       0.000000   83.500000   11.300000   33.250000    3.500000
# 75%       0.500000   88.300000   20.850000   70.050000    7.275000
# max      16.800000   96.000000   65.900000  220.400000   19.000000
#
#                BUI         FWI Classes      region
# count   242.000000  242.000000     242  242.000000
# unique         NaN         NaN       2         NaN
# top            NaN         NaN    fire         NaN
# freq           NaN         NaN     137         NaN
# mean     16.747934    7.063636     NaN    0.495868
# std      14.229690    7.442923     NaN    0.501019
# min       1.100000    0.000000     NaN    0.000000
# 25%       6.025000    0.725000     NaN    0.000000
# 50%      12.450000    4.450000     NaN    0.000000
# 75%      22.775000   11.525000     NaN    1.000000
# max      68.000000   31.100000     NaN    1.000000

# %%
# Performing EDA
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dropna(inplace=True)

# %%
len(df.iloc[0, -1])
# Out:
# 11

# %%
# Look at class balance
df["Classes  "] = df["Classes  "].str.strip()
# Update the data to the file
df.to_csv("Algerian_forest_fires_dataset_UPDATE.csv", index=False)

# %%
df.rename(columns={"Classes  ": "Classes"}, inplace=True)
